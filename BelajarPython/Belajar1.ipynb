# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x1 = np.arange(0, 8.1, 0.1)
y1 = 5* np.cos(2*x)*np.exp(-0.4*x)
x2 = np.arange(-5, 5, 0.1)
y2 = np.cos(x2)

plt.plot(x1, y1)
plt.plot(x2, y2, '.')
plt.show()

# %%
# Out:
# Python version
# 3.9.16 (main, Mar  1 2023, 18:30:21) [MSC v.1916 64 bit (AMD64)]
# Hello world
